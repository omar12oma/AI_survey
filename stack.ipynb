# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
import numpy as np
import datetime

# %%
public = pd.read_csv('survey_results_public.csv')
schema = pd.read_csv('survey_results_schema.csv')

# %%
public.head()
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
#
#                              RemoteWork  \
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
public.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 84 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ResponseId                           89184 non-null  int64
#  1   Q120                                 89184 non-null  object
#  2   MainBranch                           89184 non-null  object
#  3   Age                                  89184 non-null  object
#  4   Employment                           87898 non-null  object
#  5   RemoteWork                           73810 non-null  object
#  6   CodingActivities                     73764 non-null  object
#  7   EdLevel                              87973 non-null  object
#  8   LearnCode                            87663 non-null  object
#  9   LearnCodeOnline                      70084 non-null  object
#  10  LearnCodeCoursesCert                 37076 non-null  object
# ...

# %%
public['AISelect'].unique() #Do you currently use AI tools in your development process?
# Out:
# array([nan, 'Yes', "No, and I don't plan to", 'No, but I plan to soon'],
#       dtype=object)

# %%
def plot_percentage(df, column_name):
    # Get the value counts for the specified column
    status_vals = df[column_name].value_counts()
    
    # Calculate percentages
    status_percentages = (status_vals / status_vals.sum()) * 100
    print(status_percentages)

    # Plotting
    status_percentages.plot(kind="bar")
    plt.ylabel("Percentage")
    plt.xlabel("Values")
    plt.title("Percentage of Each Value in '{}' column".format(column_name))
    plt.show()

# %%
def plot_percentage_comparison(df1, df2, column_name,Title):
    # Get the value counts for the specified column for both dataframes
    status_vals1 = df1[column_name].value_counts()
    status_vals2 = df2[column_name].value_counts()
    
    # Calculate percentages for both dataframes
    status_percentages1 = (status_vals1 / status_vals1.sum()) * 100
    status_percentages2 = (status_vals2 / status_vals2.sum()) * 100

    # Get unique categories
    categories = sorted(set(status_percentages1.index) | set(status_percentages2.index))
    index = np.arange(len(categories))

    # Plotting
    plt.figure(figsize=(10, 6))  # Set the figure size
    width = 0.35  # Width of bars

    plt.bar(index - width/2, status_percentages1.reindex(categories, fill_value=0), width, label='all')
    plt.bar(index + width/2, status_percentages2.reindex(categories, fill_value=0), width, label='senior ')

    #plt.xlabel("Values")
    plt.ylabel("Percentage")
    plt.title(Title)
    plt.xticks(index, categories)
    plt.legend()
    plt.show()

# %%
plot_percentage(public, 'AISelect')
# Out:
# Yes                        44.379526
# No, and I don't plan to    29.805736
# No, but I plan to soon     25.814739
# Name: AISelect, dtype: float64

# %% [markdown]
# froam all developer around 45% use it and 25% plan to use it soon >> It's a good sign that it Worth it

# %%
public['YearsCodePro'].unique() # how many years have you coded professionally (as a part of your work)?
# Out:
# array([nan, '9', '23', '7', '4', '21', '3', '15', 'Less than 1 year',
#        '10', '2', '6', '14', '5', '19', '13', '16', '28', '1', '30', '11',
#        '8', '25', '32', '24', '40', '17', '45', '29', '12', '31', '20',
#        '18', '50', '27', '43', '22', '26', '38', '33', '44', '35', '34',
#        '37', '42', '41', 'More than 50 years', '47', '36', '39', '48',
#        '46', '49'], dtype=object)

# %% [markdown]
# These tools may be common for those with little experience, what about seniors?
#
# A person is called a senior if he has 5 years of experience or more

# %%
# Replace 'Less than 1 year' with '0'
public.loc[public['YearsCodePro'] == 'Less than 1 year', 'YearsCodePro'] = '0'

# Replace 'More than 50 years' with '51'
public.loc[public['YearsCodePro'] == 'More than 50 years', 'YearsCodePro'] = '51'

# Fill NaN values with 0 (or any other default value)
public['YearsCodePro'].fillna(0, inplace=True)

# Convert the column to the integer type
public['YearsCodePro'] = public['YearsCodePro'].astype(int)

# %%
public_pro=public[public['YearsCodePro']>=5]

# %%
plot_percentage(public_pro, 'AISelect')
# Out:
# Yes                        38.118711
# No, and I don't plan to    33.923750
# No, but I plan to soon     27.957539
# Name: AISelect, dtype: float64

# %% [markdown]
# from seniors around 38% use it and 28% plan to use it soon >> It seems to be more common among less experience people, but the percentage is still good among seniors

# %% [markdown]
# instde of uesing two plot one for all developer and one for professional let as use one plot for comparison

# %%
plot_percentage_comparison(public, public_pro, 'AISelect','useing AI tools?')

# %% [markdown]
# How much do you trust the accuracy of the output from AI tools as part of yourdevelopment workflow?

# %%
public['AIBen'].unique() #How much do you trust the accuracy of the output from AI tools as part of your development workflow?
# Out:
# array([nan, 'Somewhat distrust', 'Somewhat trust',
#        'Neither trust nor distrust', 'Highly distrust', 'Highly trust'],
#       dtype=object)

# %%
plot_percentage(public, 'AIBen')
# Out:
# Somewhat trust                39.298977
# Neither trust nor distrust    30.681152
# Somewhat distrust             21.711512
# Highly distrust                5.456382
# Highly trust                   2.851977
# Name: AIBen, dtype: float64

# %%
plot_percentage(public_pro, 'AIBen')
# Out:
# Somewhat trust                36.192163
# Neither trust nor distrust    32.329635
# Somewhat distrust             23.187595
# Highly distrust                6.118517
# Highly trust                   2.172089
# Name: AIBen, dtype: float64

# %%
plot_percentage_comparison(public, public_pro, 'AIBen',"trust in accuracy")

# %% [markdown]
# what about Data Scientist ?

# %%
public_DS=public[public['DevType']=='Data scientist or machine learning specialist']
public_pro_DS=public_pro[public_pro['DevType']=='Data scientist or machine learning specialist']

# %%
plot_percentage(public_DS, 'AISelect')
# Out:
# Yes                        60.012594
# No, but I plan to soon     21.410579
# No, and I don't plan to    18.576826
# Name: AISelect, dtype: float64

# %%
plot_percentage(public_pro_DS, 'AISelect')
# Out:
# Yes                        52.754982
# No, but I plan to soon     23.915592
# No, and I don't plan to    23.329426
# Name: AISelect, dtype: float64

# %%
plot_percentage_comparison(public_DS, public_pro_DS, 'AISelect','useing AI tools? "Data Scientist"')

# %%
plot_percentage(public_DS, 'AIBen')
# Out:
# Somewhat trust                44.117647
# Neither trust nor distrust    28.405573
# Somewhat distrust             18.962848
# Highly distrust                5.263158
# Highly trust                   3.250774
# Name: AIBen, dtype: float64

# %%
plot_percentage(public_pro_DS, 'AIBen')
# Out:
# Somewhat trust                41.500766
# Neither trust nor distrust    27.258806
# Somewhat distrust             21.898928
# Highly distrust                6.431853
# Highly trust                   2.909648
# Name: AIBen, dtype: float64

# %%
plot_percentage_comparison(public_DS, public_pro_DS, 'AIBen','trust in accuracy "Data Scientist"')
